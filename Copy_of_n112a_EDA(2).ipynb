# %% [markdown]
# <a href="https://colab.research.google.com/github/Jihyesh/baekjoon_python/blob/main/Copy_of_n112a_EDA(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 2*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# # **🌱 기본 과제**

# %% [markdown]
# ## **Part 1. EDA**

# %% [markdown]
# ### **1-1. 데이터 불러오기**
#
# 아래의 Tip을 활용하여 Searbon 라이브러리에 내장되어 있는 Titanic 데이터셋을 불러옵니다.
#
# > **💡 Tip**
# > - import seaborn as sns
# > - df = sns.[load_dataset](https://seaborn.pydata.org/generated/seaborn.load_dataset.html)("titanic")

# %%
# 이곳에 코드를 작성하세요.
import seaborn as sns
df = sns.load_dataset('titanic')

df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### **1-2. 데이터 분석**

# %% [markdown]
# ##### **Q1. 생존자와 사망자 중 평균 나이가 더 높은 그룹을 쓰세요.**
#
# - `Survived` column의 1은 생존자, 0은 사망자를 의미합니다.
# - **`.groupby()`**를 사용하여 생존 여부별 평균 나이를 구하세요.

# %%
# 이곳에 코드를 작성하세요.
df.groupby('survived', as_index=False).mean()
#사망지
# Out:
#    survived    pclass        age     sibsp     parch       fare  adult_male  \
# 0         0  2.531876  30.626179  0.553734  0.329690  22.117887    0.817851
# 1         1  1.950292  28.343690  0.473684  0.464912  48.395408    0.257310
#
#       alone
# 0  0.681239
# 1  0.476608

# %% [markdown]
# ##### **Q2. 사망자 중 남자의 좌석 등급의 중앙값을 쓰세요.**
#
# - **`.groupby()`**와 [`.median()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.median.html)을 사용하여 생존 여부와 성별에 따른 좌석 등급의 중앙값을 구하세요.
#   - 결과는 데이터프레임 형태로 나타내세요.

# %%
# 이곳에 코드를 작성하세요.
df.groupby(['survived','sex'], as_index=False).median()
# Out:
#    survived     sex  pclass   age  sibsp  parch      fare  adult_male  alone
# 0         0  female     3.0  24.5    1.0    0.0  15.24580         0.0    0.0
# 1         0    male     3.0  29.0    0.0    0.0   9.41665         1.0    1.0
# 2         1  female     2.0  28.0    0.0    0.0  26.00000         0.0    0.0
# 3         1    male     2.0  28.0    0.0    0.0  26.28750         1.0    1.0

# %% [markdown]
# ##### **Q3. `young` 그룹의 사망자의 비율을 반올림하여 소숫점 둘째 자리까지 쓰세요.**
#
# - **`.query()`**를 사용하여 `age` 컬럼의 데이터를 다음 세 그룹으로 나누어 차례대로 변수 `young`, `middle`, `old`에 저장합니다.
#   - `young`: 20세 미만
#   - `middle`: 20세 이상 60세 미만
#   - `old`: 60세 이상
#
# - **`.value_counts()`**의 `normalize` 파라미터를 설정하여 각 그룹별 `survived` 데이터 비율을 구하세요.

# %% [markdown]
# [pandas.Series.value_counts](https://pandas.pydata.org/pandas-docs/version/0.25.0/reference/api/pandas.Series.value_counts.html)

# %%
# 이곳에 코드를 작성하세요.
young = df.query("age<20")
#young.head(20)
middle = df.query("age>=20 and age<60")
#middle.head(20)
old = df.query("age>=60")
#old.head()

young.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 16         0       3    male   2.0      4      1   29.1250        Q   Third
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 24         0       3  female   8.0      3      1   21.0750        S   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 38         0       3  female  18.0      2      0   18.0000        S   Third
# 39         1       3  female  14.0      1      0   11.2417        C   Third
# 43         1       2  female   3.0      1      2   41.5792        C  Second
# 44         1       3  female  19.0      0      0    7.8792        Q   Third
# 49         0       3  female  18.0      1      0   17.8000        S   Third
# 50         0       3    male   7.0      4      1   39.6875        S   Third
# 58         1       2  female   5.0      1      2   27.7500        S  Second
# 59         0       3    male  11.0      5      2   46.9000        S   Third
# 63         0       3    male   4.0      3      2   27.9000        S   Third
# 67         0       3    male  19.0      0      0    8.1583        S   Third
# 68         1       3  female  17.0      4      2    7.9250        S   Third
# 71         0       3  female  16.0      5      2   46.9000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 14  child       False  NaN  Southampton    no   True
# 16  child       False  NaN   Queenstown    no  False
# 22  child       False  NaN   Queenstown   yes   True
# 24  child       False  NaN  Southampton    no  False
# 27    man        True    C  Southampton    no  False
# 38  woman       False  NaN  Southampton    no  False
# 39  child       False  NaN    Cherbourg   yes  False
# 43  child       False  NaN    Cherbourg   yes  False
# 44  woman       False  NaN   Queenstown   yes   True
# 49  woman       False  NaN  Southampton    no  False
# 50  child       False  NaN  Southampton    no  False
# 58  child       False  NaN  Southampton   yes  False
# 59  child       False  NaN  Southampton    no  False
# 63  child       False  NaN  Southampton    no  False
# 67    man        True  NaN  Southampton    no   True
# 68  woman       False  NaN  Southampton   yes  False
# 71  woman       False  NaN  Southampton    no  False

# %%
young.groupby('survived', as_index=False).mean()
# Out:
#    survived    pclass        age     sibsp     parch       fare  adult_male  \
# 0         0  2.800000  13.535294  1.529412  0.729412  26.048333    0.517647
# 1         1  2.240506  10.305949  0.670886  0.924051  37.977586    0.063291
#
#       alone
# 0  0.423529
# 1  0.227848

# %%
young['survived'].value_counts(normalize=True)
# Out:
# 0    0.518293
# 1    0.481707
# Name: survived, dtype: float64

# %% [markdown]
# ### **1-3. 데이터 시각화**

# %% [markdown]
# ##### **Q4. bar 높이가 가장 높은 대상을 쓰세요.**
#
# - 생존 여부와 성별에 따른 평균 요금을 bar plot으로 나타냅니다.

# %%
# 이곳에 코드를 작성하세요.
df2 = df.groupby(['survived','sex'])['fare'].mean()
df2.head()
# Out:
# survived  sex
# 0         female    23.024385
#           male      21.960993
# 1         female    51.938573
#           male      40.821484
# Name: fare, dtype: float64

# %%
df2.plot(kind='bar');

# %% [markdown]
# # **🥇 도전과제**

# %% [markdown]
# ## **Part 2. 시각화**

# %% [markdown]
# ### **2-1. Categorical Variable의 시각화**

# %% [markdown]
# ##### **`survived`의 비율을 확인하세요.**
#
# - Matplotlib의 [`.pie`](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html)를 사용하여 `survived` 컬럼의 비율을 시각화해 봅니다.

# %%
# 이곳에 코드를 작성하세요.

# %% [markdown]
# ##### **pclass의 도수를 확인하세요.**
#
# - Seaborn의 [`.countplot()`](https://seaborn.pydata.org/generated/seaborn.countplot.html)을 사용하여 `pclass` 컬럼의 도수를 시각해 봅니다.

# %%
# 이곳에 코드를 작성하세요.

# %% [markdown]
# ### **2-2. Continuous variables의 시각화**

# %% [markdown]
# ##### **Age column을 histogram으로 나타내세요.**
#
# - Age column을 histogram으로 나타낼 때, np.arange(0, df.Age.max()+bin_size, bin_size) 에서 bin의 개수가 8이 되도록 bin_size 값을 설정하여 시각화해 보세요.

# %%
# 이곳에 코드를 작성하세요.
